# %%
import os
import sys
home_dir = "../"
module_path = os.path.abspath(os.path.join(home_dir))
if module_path not in sys.path:
    sys.path.append(module_path)

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import utility.pickle_utils as pickle_utils

# %%
# to generate the weights run analysis/x_model.py

# %%
w=pickle_utils.load(home_dir+"analysis/weights/epbd_feature_extractor_kernel_weights.pkl")
w.shape
# Out:
# (768, 6, 7)

# %%
x = np.mean(w, axis=(0,2))
plt.plot(x)
# y = np.std(w, axis=(0,2))
# plt.plot(y)
plt.show()

# %%
x = np.mean(w, axis=0)
print(x.shape)
sns.boxplot(np.transpose(x))
# sns.boxplot(x)
plt.show()
# Out:
# (6, 7)

# %%
x = np.mean(w, axis=2)
print(x.shape)
sns.boxplot(x)
plt.show()
# Out:
# (768, 6)

# %%
y = np.mean(w, axis=0)
print(y.shape)
plt.imshow(y, aspect="auto", cmap="YlGn", interpolation="nearest") # inferno_r, YlGn'
plt.colorbar()
plt.show()
# Out:
# (6, 7)

# %%
for i in range(y.shape[0]):
    print(np.mean(y[i]), np.std(y[i]))
# Out:
# 0.000334237 0.0015516334
# -0.0009025358 0.0029285694
# 0.0011283784 0.004035671
# 0.0003418152 0.0032121
# -0.0025764203 0.0017363243
# -0.001432305 0.0037415859

# %%
y = np.mean(w, axis=1)
print(y.shape)
plt.imshow(y, aspect="auto", cmap="YlGn", interpolation="nearest") # inferno_r, YlGn'
plt.colorbar()
plt.show()
# Out:
# (768, 7)

# %%
y = np.mean(w, axis=2)
print(y.shape)
plt.imshow(y, aspect="auto", cmap="YlGn", interpolation="nearest") # inferno_r, YlGn'
plt.colorbar()
plt.show()
# Out:
# (768, 6)
